# %% [markdown]
# <a href="https://colab.research.google.com/github/SayanAndrews2002/New-York-City-Motor-Vehicle-Collisions-Data-Science-Project/blob/main/Time_Series_New_York_City_Motor_Vehicle_Collisions_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🚗 **<font color='crimson'>** **Analyzing Traffic Crashes in New York City: Understanding Patterns and Improving Safety for Vulnerable Road Users 🚗**</font>
# ---

# %% [markdown]
# ## <font color='crimson'>**Project Information and Background:**</font>

# %% [markdown]
# **Project Description:**
# Background:
# Traffic accidents are a significant public safety issue, particularly in densely populated urban areas like New York City. The high volume of vehicles, pedestrians, and cyclists on the roads leads to frequent collisions, resulting in injuries, fatalities, and substantial economic costs. Understanding the factors that contribute to these accidents is essential for improving road safety and implementing targeted interventions to protect vulnerable road users, such as pedestrians, cyclists, and motorcyclists.
#
# In recent years, the Department of Transportation (DOT) and the Federal Highway Administration (FHWA) have focused on reducing the number of traffic-related fatalities and injuries, particularly in underserved and high-risk areas. However, the complexity of traffic crashes, influenced by factors such as location, time, road design, and weather, calls for a detailed analysis of patterns and trends to inform decision-making and policy.
#
# Project Description:
# This project aims to analyze traffic crash data from New York City to identify patterns in crash frequency, severity, and location. By examining various factors, such as boroughs, intersection types, time of day, and external influences like the COVID-19 pandemic, the goal is to gain actionable insights into the areas where interventions can be made to enhance safety.
#
# Key areas of focus in this analysis include:
#
# Crash Hotspots: Identifying intersections and areas with the highest number of crashes, injuries, and fatalities.
# Crash Severity Analysis: Examining the relationship between crash severity (injuries vs. fatalities) and various factors such as location, traffic volume, and road features.
# Impact of External Factors: Understanding the influence of events like the COVID-19 pandemic on crash rates and patterns.
# Borough-wise and Geographic Analysis: Analyzing how traffic accidents vary across different neighborhoods and boroughs within New York City, with a focus on underserved and vulnerable communities.
# The insights gained from this project are intended to inform future recommendations for the Department of Transportation, Federal Highway Authority, and other city planning entities to improve road safety and reduce traffic-related harm.
#
# Project Goals:
# To uncover high-crash zones within New York City through heatmaps and geospatial analysis.
# To analyze crash severity by borough and suggest potential measures to reduce fatalities and injuries.
# To investigate how time-related and external factors, like COVID-19, have influenced traffic accidents.
# To provide actionable recommendations for enhancing safety for vulnerable road users based on data analysis.
# Why This Project Matters:
# Traffic accidents have lasting effects on individuals, families, and communities, often resulting in severe injury or loss of life. By conducting a detailed, data-driven analysis, this project contributes to improving transportation safety, particularly for pedestrians and cyclists, who are at a higher risk in busy urban environments. The results and insights from this study could guide future policies, infrastructure changes, and public awareness campaigns to create safer streets in New York City and similar urban areas.

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## <font color='crimson'>**An Introduction to Python Programming**</font>

# %% [markdown]
# Python is a programming language often used to analyze data.
#
# Python is open-source, which means it's free to use and distribute, even for commercial purposes. Python's versatility allows it to be used for web development, data visualization, artificial intelligence, scientific computing, and more.
#
# Python's extensive standard library, along with its powerful third-party packages, enable developers and data scientists to perform a vast array of tasks.
#
# For those looking to dive deeper into Python, here are some valuable resources:
# - [The Official Python Documentation](https://docs.python.org/3/) – Offers comprehensive guides and reference materials for Python leaners.
# - [Real Python](https://realpython.com/) – Provides tutorials and articles for Python developers of all skill levels.
# - [PyCon](https://pycon.org/) – The largest annual gathering for the Python community, which is useful for learning from experts and discovering the latest developments in the Python ecosystem.
# - [Python for Everybody](https://www.py4e.com/) – A book and website by Dr. Charles Severance that offers a free course on Python for beginners.

# %% [markdown]
# ## <font color='crimson'>**Data Preparation**</font>
# GOAL: The main goal of this milestone is to set up the environment, install the required packages, learn how to access data and do some basic exploratory data analysis.

# %% [markdown]
# **Step 1:** Setting up libraries and installing packages
#
# A **library** is a collection of code that you can use in your programs, while a **package** is a folder that contains libraries or other packages, organized for easy use.
#
# To install a library, we'll use the following format:
# ```python
#  import <library name> as <shortname>
# ```
# We use a *short name* since it is easier to refer to the package to access functions and also to refer to subpackages within the library. Think of it as a nickname for easier reference!

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import folium

# %% [markdown]
# These are the libraries that will help us throughout this project.

# %% [markdown]
# What each library does:
#
#
# > * Pandas: Pandas is a powerful library for data manipulation and analysis in Python. It provides easy-to-use data structures like DataFrames and Series, allowing users to handle and preprocess structured data efficiently, including tasks like cleaning, filtering, merging, and aggregating datasets.
# > * Matplotlib: Matplotlib is a versatile library for creating static, interactive, and animated visualizations in Python. It offers a wide variety of chart types, such as line plots, bar charts, scatter plots, and histograms, providing extensive customization options to suit different visualization needs.
# > * Seaborn: Seaborn is built on top of Matplotlib and specializes in statistical data visualization. It simplifies the creation of aesthetically pleasing and informative plots, such as heatmaps, box plots, and violin plots, while seamlessly integrating with Pandas data structures for ease of use.

# %% [markdown]
# Let’s access our data. We will be using the [NYC OpenData Motor Vehicle Collisions - Crashes dataset](https://data.cityofnewyork.us/Public-Safety/Motor-Vehicle-Collisions-Crashes/h9gi-nx95). According to NYC Open Data, "each row represents a crash event. The Motor Vehicle Collisions data tables contain information from all police reported motor vehicle collisions in NYC."

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# TODO: Read the data using pandas read_csv function
data = pd.read_csv("/content/drive/MyDrive/Motor_Vehicle_Collisions_-_Crashes_20250103.csv")
# Out:
# <ipython-input-3-2e2706bdaf86>:2: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("/content/drive/MyDrive/Motor_Vehicle_Collisions_-_Crashes_20250103.csv")

# %% [markdown]
# **Step 3:** Let's see what the data looks like. We can use the `head` function which returns the first 5 rows of the dataset.

# %%
# TODO: Print the first 5 rows of the data using head function of pandas
data.head()
# Out:
#    CRASH DATE CRASH TIME   BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0  09/11/2021       2:39       NaN      NaN        NaN        NaN
# 1  03/26/2022      11:45       NaN      NaN        NaN        NaN
# 2  06/29/2022       6:55       NaN      NaN        NaN        NaN
# 3  09/11/2021       9:35  BROOKLYN  11208.0  40.667202 -73.866500
# 4  12/14/2021       8:13  BROOKLYN  11233.0  40.683304 -73.917274
#
#                   LOCATION           ON STREET NAME CROSS STREET NAME  \
# 0                      NaN    WHITESTONE EXPRESSWAY         20 AVENUE
# 1                      NaN  QUEENSBORO BRIDGE UPPER               NaN
# 2                      NaN       THROGS NECK BRIDGE               NaN
# 3    (40.667202, -73.8665)                      NaN               NaN
# 4  (40.683304, -73.917274)          SARATOGA AVENUE    DECATUR STREET
#
#            OFF STREET NAME  ...  CONTRIBUTING FACTOR VEHICLE 2  \
# 0                      NaN  ...                    Unspecified
# ...

# %%
# TODO: Describe the data using the describe function of pandas
desc_stats = data.describe()
desc_stats
# Out:
#            LATITUDE     LONGITUDE  NUMBER OF PERSONS INJURED  \
# count  1.906898e+06  1.906898e+06               2.146419e+06
# mean   4.062074e+01 -7.373944e+01               3.194339e-01
# std    2.049563e+00  3.840054e+00               7.079482e-01
# min    0.000000e+00 -2.013600e+02               0.000000e+00
# 25%    4.066757e+01 -7.397469e+01               0.000000e+00
# 50%    4.072055e+01 -7.392705e+01               0.000000e+00
# 75%    4.076962e+01 -7.386674e+01               0.000000e+00
# max    4.334444e+01  0.000000e+00               4.300000e+01
#
#        NUMBER OF PERSONS KILLED  NUMBER OF PEDESTRIANS INJURED  \
# count              2.146406e+06                   2.146437e+06
# mean               1.541647e-03                   5.809535e-02
# std                4.143963e-02                   2.471543e-01
# min                0.000000e+00                   0.000000e+00
# 25%                0.000000e+00                   0.000000e+00
# ...

# %% [markdown]
# 1. Latitude & Longitude: The latitude and longitude indicate where the crashes are occurring. However, there are some data points with latitude and longitude values of 0, which is likely due to missing or inaccurate data.
#
# 2. Number of Persons Injured: On average, each crash has around 0.305 injuries. The maximum number of injuries in a single crash is 43.
#
# 3. Number of Persons Killed: Fatalities are rare, with an average of 0.00146 deaths per crash. The maximum number of deaths in one crash is 8.
#
# 4. Number of Pedestrians, Cyclists, and Motorists Injured/Killed: These columns provide a breakdown of the injuries and fatalities by type of individual involved.
#
# 5. Collision ID: This is a unique identifier for each crash.

# %% [markdown]
# ---

# %% [markdown]
# ##<font color='crimson'> **Data Ethics, Pre-Processing, and Exploration** </font>
# GOAL: The main goal of this milestone is to assess the dataset, find missing values, and decide what to do with those missing data points.

# %% [markdown]
# Based on the resources above and outside knowledge, what are some potential bias issues related to the availability of data from well-resourced communities as compared to under-resourced communities? How might bias show up in our dataset?
#
# > Bias in data can arise when the dataset disproportionately represents certain communities over others. In the context of transportation data, this can manifest in several ways:
#
# Underreporting in Under-Resourced Communities:
# Data from well-resourced communities might be more readily available, better documented, and have more consistent reporting practices. In contrast, under-resourced communities may face challenges in accurate data collection, such as fewer resources for traffic monitoring, police reporting, or data management. This can lead to underreporting of crashes, potentially skewing the data and misrepresenting the actual frequency and nature of collisions in these areas.
#
# Bias in Traffic Enforcement:
# In some cases, certain communities may experience over-policing, leading to an overrepresentation of incidents in the dataset for those areas, while other areas may have less enforcement or fewer resources for incident reporting. This can introduce bias in the data regarding which communities are perceived to be more prone to accidents, when in fact, they may be underrepresented or inaccurately portrayed due to reporting practices.
#
# Disparities in Accident Severity Reporting:
# There may be bias in how accidents are reported in different communities. For example, in wealthier communities, there may be a higher likelihood of more detailed reporting due to better access to healthcare or legal resources, while in under-resourced communities, less thorough documentation could result in underestimating the severity of crashes or failing to capture key factors such as injuries.
#
# Geographic Disparities:
# In some under-resourced communities, there may be a lack of infrastructure or safety measures that could influence the likelihood and severity of crashes. Without robust data collection, these contributing factors might not be adequately captured, leading to an incomplete picture of traffic safety.
#
# To address these biases, it’s essential to ensure that the data is representative and that we carefully consider the implications of any missing or incomplete data. In this dataset, missing values or data gaps could potentially reflect these broader issues, and how we handle those missing values (e.g., through imputation or exclusion) may influence the analysis and outcomes of the project.

# %% [markdown]
# **Step 2:**
# Check the dataset for missing values.

# %%
# Find the number of missing values in each column
missing_values = data.isnull().sum()

# Turn the missing value counts into percentages
missing_values_percentage = (missing_values / len(data)) * 100

# Return counts and percentages of missing values in each column
missing_data = pd.DataFrame({'Missing Values': missing_values, 'Percentage (%)': missing_values_percentage})

# Sort by percentage of missing values in descending order
missing_data.sort_values(by='Percentage (%)', ascending=False)
# Out:
#                                Missing Values  Percentage (%)
# VEHICLE TYPE CODE 5                   2137129       99.566351
# CONTRIBUTING FACTOR VEHICLE 5         2136833       99.552561
# VEHICLE TYPE CODE 4                   2112540       98.420778
# CONTRIBUTING FACTOR VEHICLE 4         2111283       98.362216
# VEHICLE TYPE CODE 3                   1997699       93.070470
# CONTRIBUTING FACTOR VEHICLE 3         1991879       92.799323
# OFF STREET NAME                       1777971       82.833598
# CROSS STREET NAME                      818348       38.125880
# ZIP CODE                               665774       31.017635
# BOROUGH                                665511       31.005382
# ON STREET NAME                         460839       21.469952
# VEHICLE TYPE CODE 2                    420401       19.585993
# CONTRIBUTING FACTOR VEHICLE 2          338481       15.769436
# LOCATION                               239539       11.159843
# ...

# %% [markdown]
# Here's an overview of the missing values in the dataset:
#
# Columns like VEHICLE TYPE CODE 5, CONTRIBUTING FACTOR VEHICLE 5, VEHICLE TYPE CODE 4, and so on have a high percentage of missing values. This is expected since not all crashes involve multiple vehicles or factors.
#
# OFF STREET NAME and CROSS STREET NAME have significant missing values. This could be due to crashes occurring in locations where these details aren't applicable or weren't recorded.
#
# ZIP CODE, BOROUGH, and ON STREET NAME also have missing values. This might be due to incomplete data entry or crashes occurring in areas where these specifics aren't easily determinable.
#
# LOCATION, LATITUDE, and LONGITUDE have the same count of missing values, indicating that when one is missing, the others are likely missing as well.

# %% [markdown]
# **Step 3:** Create a bar chart to display the top 10 contributing factors (e.g. backing up unsafely, unsafe lane changing, etc.) to crashes within the dataset.

# %%
top_factors = data['CONTRIBUTING FACTOR VEHICLE 1'].value_counts().head(10)

plt.figure(figsize=(12, 7))
# Plotting the top contributing factors
sns.barplot(x=top_factors.index, y=top_factors.values, palette="magma")

plt.title('Top 10 Contributing Factors to Crashes', fontsize=16)
plt.xlabel('Contributing Factor', fontsize=14)
plt.ylabel('Number of Crashes', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-7-49de0495cf37>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_factors.index, y=top_factors.values, palette="magma")

# %% [markdown]
# Besides for "Unspecified," what are the top 3 contributing factors that cause the most crashes?
#
# > *  Driver Inattention/Distraction
# > *  Failure to Yield Right-of-Way
# > *  Following Too Closely

# %% [markdown]
# > *   Recommendations to New and Current Drivers:
#
# Minimize Distractions: Drivers should remain fully focused on the road at all times. This means avoiding the use of mobile phones, limiting interactions with passengers, and refraining from engaging in other activities that could distract them from driving. Consider using hands-free devices or voice commands for navigation and calls.
#
# Yield Right-of-Way Appropriately: It's critical to understand and respect traffic rules, especially in situations where the right of way is unclear. Drivers should always be prepared to yield when necessary to avoid collisions, particularly at intersections and when merging onto highways.
#
# Maintain a Safe Following Distance: Drivers should always keep a safe distance between their vehicle and the one ahead, especially in high-traffic conditions or bad weather. Following the "3-second rule" (or more in adverse conditions) can give drivers enough time to react if the vehicle ahead suddenly stops or slows down.
#
# Stay Educated and Aware: Continuing education on safe driving practices, attending defensive driving courses, and staying informed about the latest traffic laws can help drivers make safer decisions on the road. This is especially important in urban or high-traffic areas, where the risk of accidents is higher.
#
# Use Technology Wisely: Modern cars often come equipped with features like lane-assist, adaptive cruise control, and collision warning systems. Drivers should familiarize themselves with these features and use them to enhance safety. However, it's essential not to rely on technology alone—drivers should remain actively engaged in the driving process.
#
# By addressing these key contributing factors and taking proactive measures, drivers can significantly reduce the likelihood of being involved in crashes and help make the roads safer for everyone.

# %% [markdown]
# **Step 4:** Now, let's create another bar chart to determine which vehicle types were involved in the most crashes.

# %%
top_vehicle_types = data['VEHICLE TYPE CODE 1'].value_counts().head(10)

# Plotting the top vehicle types
plt.figure(figsize=(12, 7))
sns.barplot(x=top_vehicle_types.index, y=top_vehicle_types.values, palette="cividis")

plt.title('Top 10 Vehicle Types Involved in Crashes', fontsize=16)
plt.xlabel('Vehicle Type', fontsize=14)
plt.ylabel('Number of Crashes', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-8-4bea998b7862>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_vehicle_types.index, y=top_vehicle_types.values, palette="cividis")

# %% [markdown]
# What are the top 3 vehicles that were most involved in crashes?
#
#
# > *   Sedan
# > *   Station Wagon/Sports Utility Vehicles
# > *   Passenger Vehicle

# %% [markdown]
# > *  There are several potential reasons why vehicle types like "Sedan[s]," "Station Wagon[s]," and "Passenger Vehicle[s]" might be involved in a larger number of crashes, injuries, and deaths compared to other vehicle types. Here are some factors to consider:
#
# 1. Prevalence on the Road:
# Sedans, Station Wagons, and Passenger Vehicles are some of the most common types of vehicles on the road. Since they make up a large portion of the overall vehicle fleet, it stands to reason that these vehicles would be involved in a higher number of crashes simply due to their frequency.
# The more vehicles there are of a particular type, the more likely it is for them to be involved in accidents, even if the risk per vehicle is similar across types.
# 2. Driver Behavior and Demographics:
# Sedans and Passenger Vehicles are often driven by a wide demographic, including both experienced and inexperienced drivers. Inexperienced or younger drivers may be more prone to distractions, risky driving behavior (like speeding), or poor decision-making in certain situations, which could increase crash frequency for these common vehicle types.
# Additionally, these vehicles might be driven by individuals who are commuting for work or family-related activities, contributing to greater exposure to traffic accidents compared to those who may drive less frequently or in less congested areas (e.g., owners of trucks or SUVs).
# 3. Vehicle Usage and Purpose:
# Sedans and Station Wagons are typically used for daily commuting, long road trips, and family transport. This increases the chances of these vehicles being on the road in varying traffic conditions, such as during rush hours, adverse weather, or in areas with higher accident rates.
# Passenger vehicles are also often used for more diverse purposes like shopping, dropping children at school, etc. The high frequency of these trips increases exposure to accidents.
# 4. Crash Dynamics and Vulnerability:
# Sedans and Station Wagons might be more vulnerable in certain types of collisions, especially those involving larger vehicles like trucks or SUVs. In high-impact crashes, these lighter and smaller vehicles might suffer more severe damage, leading to a higher incidence of injuries and fatalities.
# These vehicles may also be more likely to be involved in side-impact collisions, which are statistically more dangerous than rear-end collisions, especially when side airbags or structural reinforcements are less advanced compared to larger vehicles.
# 5. Urban and Suburban Traffic Patterns:
# Passenger vehicles are more commonly found in urban and suburban environments, where traffic density is higher. High traffic volume increases the likelihood of accidents occurring, even if individual vehicles are driven safely. Sedans and station wagons, being more common in these areas, are disproportionately represented in crash statistics.
# In contrast, larger vehicles like trucks, while perhaps more dangerous in a crash, are less likely to be involved in accidents simply due to their less frequent presence in crowded urban environments.
# 6. Increased Exposure to Risky Situations:
# Sedans and Passenger Vehicles are often involved in situations where multiple vehicles are interacting, such as intersections or densely packed highway traffic. These vehicles might be more likely to be involved in multi-vehicle collisions or situations where driver error (such as failure to yield or distracted driving) leads to accidents.
# 7. Lack of Specialized Safety Features:
# While many sedans and passenger vehicles have robust safety features, some may lack the more advanced safety technology found in newer or higher-end models. Larger vehicles, like SUVs, may offer better visibility, more safety features, and enhanced protection, reducing their likelihood of being involved in accidents or sustaining severe damage.
# Station wagons, often used by families, may not be equipped with the same level of collision avoidance or advanced safety technologies (e.g., automatic emergency braking, lane-keeping assist) as newer vehicle types, making them more vulnerable in an accident.

# %% [markdown]
# Looking at the bar chart:
#
#
# > 1) What do you notice about the x-axis of the bar chart?
# Clarity and Labeling Issues: The x-axis, which represents the vehicle types, may have long or inconsistent labels, making it difficult for the viewer to read and interpret the chart accurately. Vehicle types with longer names might overlap or become illegible when displayed in a horizontal bar chart.
# Potential for Clutter: If there are too many unique vehicle types, the x-axis might get cluttered, especially if the chart is showing the top 10 types. This could reduce the readability and interpretability of the chart.
# 2) What would you recommend we do to improve the bar chart, based on the x-axis, and why?
# Rotate and Adjust Label Orientation: If the x-axis labels (vehicle types) are long, rotate them 45° or 90° to prevent overlap and ensure they are readable. This will make better use of space and improve the chart's clarity.
# Limit the Number of Categories Displayed: If there are too many vehicle types, consider reducing the number of categories displayed (e.g., focusing on the top 10 or 15) to prevent overcrowding of the x-axis and allow for a cleaner, more focused visualization.
# Use Abbreviations or Groupings: Where possible, use abbreviated labels or group similar vehicle types together (e.g., "Passenger Cars" for sedans, coupes, and hatchbacks) to make the chart less cluttered while still conveying the necessary information.
# Increase the Figure Size: If space allows, increasing the overall size of the figure can also make the x-axis labels more readable by providing more space for them.
# 3) What recommendation would you make to those who are collecting and/or inputting data into this dataset?
# Consistent and Standardized Vehicle Classification: Ensure that vehicle types are classified consistently and standardized throughout the dataset. This helps prevent discrepancies like variations in how the same vehicle type is recorded (e.g., "sedan" vs. "sedan type" or different spellings like "passenger vehicle" vs. "passenger car").
# Use Clear, Concise Labels: When inputting vehicle types, try to limit the length of labels to make them easier to visualize and analyze. Additionally, consider using standardized categories (such as "Sedans", "SUVs", "Trucks", etc.) instead of vague or overly specific labels.
# Validate Data Integrity: Periodically check for data entry errors, such as empty or incorrect values for vehicle type. Missing or incorrect data can affect analysis and lead to misleading results.
# Ensure Consistency Across Records: If possible, ensure that the vehicle type information is consistent across different datasets, making it easier to merge and analyze data over time.

# %% [markdown]
# **Step 5:**  A DataFrame is a two-dimensional and potentially heterogeneous tabular data structure with labeled axes (rows and columns). DataFrames allow for storing, manipulating, and retrieving data in a structured form, serving as the primary data structure for a multitude of data processing tasks. It is used with Python libraries like pandas.
#
# Let's graph the *types* of crashes within this dataset and their frequencies.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Aggregating data - Complete for Cyclist and Motorist
types_of_crashes = {
    'Pedestrian Injuries': data['NUMBER OF PEDESTRIANS INJURED'].sum(),
    'Cyclist Injuries': data['NUMBER OF CYCLIST INJURED'].sum(),  # Complete
    'Motorist Injuries': data['NUMBER OF MOTORIST INJURED'].sum(),  # Complete
    'Pedestrian Deaths': data['NUMBER OF PEDESTRIANS KILLED'].sum(),
    'Cyclist Deaths': data['NUMBER OF CYCLIST KILLED'].sum(),  # Complete
    'Motorist Deaths': data['NUMBER OF MOTORIST KILLED'].sum()  # Complete
}

# Converting to DataFrame for easier plotting - we want the items in the dictionary, use the items function
crash_types_df = pd.DataFrame(list(types_of_crashes.items()), columns=['crash Type', 'Count'])

# Plot
plt.figure(figsize=(12, 7))
sns.barplot(x='Count', y='crash Type', data=crash_types_df, palette="mako")
plt.title('Types of Crashes and Their Frequencies')
plt.xlabel('Count')
plt.ylabel('Type of Crash')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-9-d57605f05a9e>:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Count', y='crash Type', data=crash_types_df, palette="mako")

# %% [markdown]
# Recommendations based on the data:
#
# > *  Analysis of the Chart:
# The chart shows the frequency of injuries and deaths for different types of crashes: pedestrians, cyclists, and motorists. Key points to notice are:
#
# Motorist Injuries and Deaths: Motorists are typically involved in the highest number of injuries and deaths, followed by pedestrians and cyclists. This is likely reflective of the fact that there are generally more motorists on the road than pedestrians or cyclists.
# Cyclist and Pedestrian Injuries and Deaths: While fewer in number compared to motorists, cyclist and pedestrian injuries and deaths are still significant. These groups may be more vulnerable on the road due to their lack of protective barriers (e.g., vehicles) in the event of a collision.
# Recommendations for the Department of Transportation:
# Based on the data in the chart, here are a few recommendations:
#
# Increase Safety Measures for Vulnerable Road Users:
#
# The high number of pedestrian and cyclist injuries and deaths calls for increased safety measures such as designated bike lanes, pedestrian-friendly intersections, and improved signage to alert drivers to areas with higher pedestrian and cyclist traffic.
# Consider introducing protected crossings or speed limits in high pedestrian/cyclist areas to reduce accidents.
# Focus on Driver Education:
#
# Although motorist injuries and deaths are higher, the fact that cyclists and pedestrians still experience a significant number of accidents suggests that drivers might not be adequately aware of these vulnerable road users. Implementing driver awareness campaigns focusing on safe passing distances and yielding to pedestrians/cyclists could help reduce these types of accidents.
# Improve Data Collection for Vulnerable Road Users:
#
# It might be beneficial to improve the granularity of data collected for pedestrians and cyclists. For instance, breaking down cyclist and pedestrian injuries by cause (e.g., distracted driving, failure to yield) could help in crafting more targeted interventions.
# Infrastructure Investment:
#
# Investing in infrastructure improvements such as better road design for pedestrians and cyclists can reduce injuries and deaths. This could include adding crosswalks, bike racks, and lighting in high-risk areas to improve visibility.
# Legislative Action on Distracted Driving:
#
# If data shows that many crashes are due to driver inattention/distraction, the Department of Transportation could work with local governments to push for stronger legislation on distracted driving, such as stricter enforcement of texting and driving laws.
# By focusing on these areas, the Department of Transportation can take steps toward reducing both motorist and vulnerable road user injuries and deaths.

# %% [markdown]
# ---

# %% [markdown]
# ##<font color='crimson'> **Time Series Analysis**</font>
# GOAL: The main goal of this milestone is to dive deeper into Time Series Analysis in order to better understand our data's trends over time.

# %% [markdown]
# about TSA:
# > *  Time Series Analysis (TSA) is a statistical technique used to analyze data points collected or recorded at specific time intervals. It helps identify patterns and structures over time, which can be broken down into three main components: trend, seasonality, and residuals. The trend represents the long-term movement or direction in the data, while seasonality reflects regular, repeating patterns within specific periods (such as monthly or yearly cycles). The residual component consists of the random noise or fluctuations that can't be explained by the trend or seasonality. By understanding these components, TSA allows us to forecast future data, detect anomalies, and make informed decisions based on time-dependent data.

# %% [markdown]
# **Step 2:** Let's begin by creating a chart that displays the average number of crashes per hour of the day. This will help us understand whether additional factors are contributing to crashes - i.e. rush hour, school dismissal time, night fall, etc.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Load the dataset
file_path = "/content/drive/MyDrive/Motor_Vehicle_Collisions_-_Crashes_20250103.csv"
data = pd.read_csv(file_path)

# Convert 'CRASH DATE' and 'CRASH TIME' to datetime
data['CRASH DATE'] = pd.to_datetime(data['CRASH DATE'])
data['CRASH TIME'] = pd.to_datetime(data['CRASH TIME'], format='%H:%M')

# Time of Day Analysis
data['Hour of Day'] = data['CRASH TIME'].dt.hour

# Group by 'Hour of Day' and calculate the average number of crashes per hour
average_crashes_per_hour = data.groupby('Hour of Day').size()

# Plot the average number of crashes
plt.figure(figsize=(12, 6))
sns.barplot(x=average_crashes_per_hour.index, y=average_crashes_per_hour.values, palette="viridis")
plt.title('Average Number of Crashes per Hour of Day')
plt.xlabel('Hour of Day')
plt.ylabel('Average Number of Crashes')
plt.xticks(range(0, 24))
plt.show()
# Out:
# <ipython-input-10-cecbf37eb8ca>:7: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_path)
# <ipython-input-10-cecbf37eb8ca>:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=average_crashes_per_hour.index, y=average_crashes_per_hour.values, palette="viridis")

# %% [markdown]
# Which time of the day sees the most crashes and why?
#
# > *  The time of day with the most crashes is often during rush hours, typically between 8-9 AM and 4-6 PM, as people are commuting to and from work or school. These periods tend to see higher traffic volume, which increases the likelihood of accidents. Additionally, late-night hours may also see a spike due to factors such as fatigue, impaired driving, and reduced visibility.
#
# Recommendations:
# Rush Hours: Efforts to reduce crashes during rush hours could include better traffic management, improving infrastructure, or promoting safe driving campaigns.
# Late-Night Hours: Increased law enforcement and awareness around impaired driving could help reduce accidents during nighttime.

# %% [markdown]
# **Step 3:**
# Plot a graph to determine how COVID-19 impacted the number of crashes per month, if at all.

# %%
# Convert 'CRASH DATE' to datetime format
data['CRASH DATE'] = pd.to_datetime(data['CRASH DATE'])

# Group by month and year to get the number of crashes per month
monthly_crashes = data.groupby(data['CRASH DATE'].dt.to_period("M")).size()

# Plotting the trend over time
plt.figure(figsize=(15, 7))
monthly_crashes.plot()
plt.title('Number of Crashes per Month', fontsize=16)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Number of Crashes', fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# What does the graph show about the impact of COVID-19 on the number of crashes per month and why?
#
# > *  Impact of COVID-19:
# In early 2020, especially during the lockdown period, many people stayed home due to stay-at-home orders, social distancing, and restrictions on movement. This likely led to a decrease in the total number of vehicles on the road, reducing opportunities for accidents.
# There may have been a noticeable dip in crashes during the peak of the pandemic and a gradual recovery once restrictions eased and traffic volumes increased again.
# Why this occurred:
# Lockdowns and Reduced Traffic: The sharp decrease in road traffic during the lockdown period likely resulted in fewer crashes. With fewer people commuting, shopping, or engaging in social activities, there was less congestion on the roads.
# Increased Risk for Some Types of Crashes: While total crashes might have decreased, certain types of incidents (such as reckless driving or speeding) may have increased due to less traffic and fewer police on the road.
# Recovery Post-Lockdowns: As restrictions were lifted and people returned to normal activities, traffic levels and crashes likely began to rise again.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.seasonal import seasonal_decompose

# Count the number of crashes per day, group by CRASH DATE
daily_crashes = data.groupby('CRASH DATE').size()

# Set plot style
sns.set(style="darkgrid")

# Plot the daily crashes time series
plt.figure(figsize=(15, 6))
plt.plot(daily_crashes, label='Daily crashes')
plt.title('Daily Motor Vehicle Collisions in NYC')
plt.xlabel('Date')
plt.ylabel('Number of Crashes')
plt.legend()
plt.show()

# Decompose the time series
decomposition = seasonal_decompose(daily_crashes, model='additive', period=365)

# Plot the decomposed components
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(15, 12))
decomposition.trend.plot(ax=ax1)
ax1.set_title('Trend')
decomposition.seasonal.plot(ax=ax2)
ax2.set_title('Seasonality')
decomposition.resid.plot(ax=ax3)
ax3.set_title('Residuals')
plt.tight_layout()
plt.show()

# %% [markdown]
# The visualizations above provide valuable insights into the time series of daily motor vehicle collisions in New York City:
#
# 1. Time Series Plot: This shows the number of daily crashes over time. You might observe long-term trends, seasonal patterns, or significant outliers.
#
# 2. Decomposed Components:
#
#     2.1 Trend: This graph shows the long-term trend in the data, which can indicate whether crashes are increasing, decreasing, or stable over time.
#
#     2.2 Seasonality: This reveals any regular patterns that repeat over a specific period, such as yearly. It helps identify times of the year with higher or lower crash frequencies.
#
#     2.3 Residuals: These are the irregular components that cannot be attributed to the trend or seasonality. They might include random or unpredictable fluctuations.

# %% [markdown]
# Based on the *trend graph*, are we seeing an increase or a decrease in crashes between 2014 and 2022?
#
# > *  Decrease
#
#
# In what year(s) was there a significant unpredicted fluctuation and why?
#
# > *  2020-2021. COVID-19 Pandemic (2020-2021): If you observe significant fluctuations starting in 2020, it is likely due to the impact of the COVID-19 pandemic. The pandemic led to lockdowns, travel restrictions, and reduced road traffic, resulting in unexpected decreases in crashes.
#
# Major Policy or Infrastructure Changes: Any sudden fluctuations in specific years could be due to changes in traffic laws, enforcement, road infrastructure, or the introduction of new technologies such as autonomous vehicles.
#
# Natural Disasters or Extreme Weather Events: Events like hurricanes, heavy snowstorms, or other extreme weather conditions can cause temporary spikes or drops in crashes.
#
# Holidays or Special Events: Some fluctuations might also be due to specific holidays or large-scale public events that influence traffic patterns.

# %% [markdown]
# ---

# %% [markdown]
# ##<font color='crimson'>**Geospatial Analysis**</font>
# GOAL: The main goal of this milestone is to explore geospatial aspects of the dataset and get comfortable with regional analysis and geospatial visualizations.

# %% [markdown]
# Let's build a bar chart to compare and analyze the number of crashes across the five boroughs: Brooklyn (also known as Kings County), Queens, Manhattan, Bronx, and Staten Island.

# %%
# Set style
sns.set_style("whitegrid")

# Plotting the distribution of crashes by borough
plt.figure(figsize=(12, 7))

# Find the count of unique values of BOROUGHS. Hint: Use value_count function.
borough_count = data['BOROUGH'].value_counts()

# Plot the bar chart
sns.barplot(x=borough_count.index, y=borough_count.values, palette="viridis")

# Add titles and labels
plt.title('Distribution of Crashes by Borough', fontsize=16)
plt.xlabel('Borough', fontsize=14)
plt.ylabel('Number of Crashes', fontsize=14)

# Rotate x-axis labels for readability
plt.xticks(rotation=45)

# Adjust layout for better visibility
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# <ipython-input-13-108f47480323>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=borough_count.index, y=borough_count.values, palette="viridis")

# %% [markdown]
# Which borough has the highest number of crashes? Which borough has the lowest?
#
# > * Highest: Brooklyn
# > * Lowest: Staten Island
#
#
# > *  The variation in the number of crashes across different boroughs can be attributed to several factors:
#
# Population Density: Boroughs like Brooklyn, Manhattan, and Queens tend to have higher population densities compared to Staten Island. Higher population densities typically correlate with more vehicles on the road, leading to a higher number of crashes.
#
# Traffic Volume: Boroughs with more busy commercial districts, like Manhattan, may experience higher traffic volumes, leading to more frequent accidents.
#
# Road Infrastructure and Traffic Conditions: Some boroughs may have older or poorly maintained infrastructure, contributing to higher accident rates. For example, areas with more intersections, narrow roads, or insufficient lighting may see more crashes.
#
# Public Transportation Usage: Boroughs like Manhattan, which have extensive public transportation systems, may have a lower number of vehicle crashes since many people rely on buses, subways, and taxis. In contrast, boroughs like Staten Island, where public transport options are more limited, might have higher vehicle usage and crashes.
#
# Tourism and Commercial Activity: Boroughs with higher tourism (e.g., Manhattan) can experience an influx of drivers unfamiliar with the roads, which could contribute to higher crash rates.
#
# Geographic and Environmental Factors: Environmental factors such as weather patterns (e.g., snow or rain) and the natural terrain (e.g., hilly areas) can affect road conditions and lead to more accidents in certain boroughs.
#
# Understanding these factors can help the Department of Transportation prioritize improvements and interventions in specific areas to reduce crash rates.

# %%
from folium.plugins import HeatMap
import folium

# Drop rows with missing latitude and longitude values
data_geo = data.dropna(subset=['LATITUDE', 'LONGITUDE'])

# Create a base map centered around NYC
m = folium.Map(location=[40.730610, -73.935242], zoom_start=10)  # Centered around NYC

# Create a heatmap
heat_data = [[row['LATITUDE'], row['LONGITUDE']] for index, row in data_geo.iterrows()]
HeatMap(heat_data, radius=8, max_zoom=13).add_to(m)

# Save the heatmap to an HTML file
m.save("Heatmap.html")

# %% [markdown]
# Where are the concentration of crashes?
#
#
# > *  Busy urban areas: Areas with high traffic, such as downtown districts or commercial centers, typically see more crashes.
# Major intersections: Locations with complex intersections or multiple lanes often have higher accident rates.
# Near public transportation hubs: Areas with heavy foot traffic and public transport access may also see more accidents involving pedestrians, cyclists, and vehicles.
# Highway and arterial roads: Roads with fast-moving traffic or high traffic volumes are often accident hotspots.

# %% [markdown]
# **Step 3:** Next, we will begin "Severity Mapping." We'll plot crashes on the map and code them based on severity, distinguishing between crashes that resulted in injuries and those that led to fatalities. This will give us a visual representation of where severe crashes tend to occur. </br>
#
# You may initially want to code these incidents by using different colors, but it's important to think about your map and how accessible it is. Will a color-coded map be easy to read for everyone? Let's make a map that's inclusive for people with color blindness by also creating differently-shaped markers (squares, circles, and triangles) for crashes, injuries, and fatalities.

# %%
#TODO: Continue building your heatmap
# Sample a subset of the data for visualization
sample_data_severity = data_geo.sample(n=1000, random_state=42)

# Create a base map
m_severity = folium.Map(location=[40.730610, -73.935242], zoom_start=10)

# Add crashes to the map with color coding and shape coding based on severity
for index, row in sample_data_severity.iterrows():
    if row['NUMBER OF PERSONS KILLED'] > 0:
        color = "red"  # Fatalities

        folium.features.RegularPolygonMarker(
          location=[row['LATITUDE'], row['LONGITUDE']],
          number_of_sides=3,
          radius=5,
          gradient = False,
          color=color,
          fill=True,
          fill_color=color
        ).add_to(m_severity)


    elif row['NUMBER OF PERSONS INJURED'] > 0:
        color = "orange"  # Injuries
        folium.CircleMarker(
          location=[row['LATITUDE'], row['LONGITUDE']],
          radius=5,
          color=color,
          fill=True,
          fill_color=color
       ).add_to(m_severity)
    else:
        color = "green"  # No injuries or fatalities
        folium.features.RegularPolygonMarker(
          location=[row['LATITUDE'], row['LONGITUDE']],
          number_of_sides=4,
          radius=5,
          gradient = False,
          color=color,
          fill=True,
          fill_color=color
        ).add_to(m_severity)


m_severity.save("severity.html")

# %% [markdown]
# > *  Based on the results below, the intersection that seems to be the most dangerous, with the highest number of crashes, is:
#
# Latitude: 0.000, Longitude: 0.000, with 4835 crashes.
# However, this is likely an error or an invalid location (such as the origin point, 0,0, which is in the Gulf of Guinea, near Africa).
# After filtering out such invalid data points, we can focus on the next top intersections:
#
# 40.696, -73.985: 1460 crashes
# 40.820, -73.891: 1321 crashes
# 40.861, -73.913: 1288 crashes
# 40.704, -73.818: 1142 crashes
# 40.691, -74.000: 1131 crashes
# The intersections at:
#
# 40.696, -73.985 (likely near Brooklyn or Manhattan)
# 40.820, -73.891 (closer to the Bronx)
# appear to be the most dangerous, with the highest number of crashes recorded.
#
# Possible Reasons:
# High traffic areas: These intersections might be located in areas with higher traffic volumes.
# Urban areas: These are likely in more densely populated and busy areas of the city where more people are commuting or walking.
# Complexity of intersections: Busy intersections with multiple lanes, turn-offs, or crosswalks may be prone to more accidents.
# Recommendation:
# Focus on these areas for traffic safety improvements, like better signage, pedestrian crossings, or traffic signal changes.
# Increase awareness and monitoring in these high-crash zones for possible infrastructure updates to reduce accidents.

# %% [markdown]
# ---
# ---

# %%
import pandas as pd
import numpy as np

# Bin the latitude and longitude into grids
grid_size = 0.001  # Adjust grid size for your data, smaller means more detailed

# Create bins for latitude and longitude
data['lat_bin'] = (data['LATITUDE'] // grid_size) * grid_size
data['lon_bin'] = (data['LONGITUDE'] // grid_size) * grid_size

# Count crashes per grid cell
crash_counts = data.groupby(['lat_bin', 'lon_bin']).size()

# Sort by number of crashes
top_intersections = crash_counts.sort_values(ascending=False).head(10)

# Display top intersections
print(top_intersections)
# Out:
# lat_bin  lon_bin
# 0.000     0.000     4835
# 40.696   -73.985    1460
# 40.820   -73.891    1321
# 40.861   -73.913    1288
# 40.704   -73.818    1142
# 40.691   -74.000    1131
# 40.675   -73.897    1056
# 40.678   -73.898    1011
# 40.761   -73.964    1010
# 40.733   -73.871     993
# dtype: int64

# %% [markdown]
# ##<font color='crimson'>  **Self-Guided Research Question**</font>

# %% [markdown]
# > *  Here are a few research questions I am considering for this project:
#
# What are the main factors contributing to fatal accidents in New York City?
#
# This question would help identify the key patterns or conditions (such as weather, time of day, or types of vehicles involved) leading to fatalities, and could inform better safety measures.
# How do traffic accidents differ across the five boroughs of New York City in terms of severity and frequency?
#
# This question could reveal which boroughs are more prone to accidents and why, and could be used for targeted intervention programs in high-risk areas.
# How has the COVID-19 pandemic affected traffic accident patterns in NYC?
#
# Analyzing traffic patterns before, during, and after COVID-19 lockdowns could provide insights into changes in driving behavior and accident rates, influencing future urban planning and safety measures.
# What is the impact of weather conditions on the frequency and severity of car accidents in NYC?
#
# By analyzing accident data in relation to weather data, we can better understand how adverse weather conditions contribute to crashes and inform drivers and policymakers.

# %% [markdown]
# > *  For this project, I’ve decided to focus on the following research question:
#
# "How do traffic accidents differ across the five boroughs of New York City in terms of severity and frequency?"
#
# Why I chose this question:
# Community Impact: Understanding which boroughs experience the highest number of crashes and which are most affected by serious injuries or fatalities can help allocate resources for safety initiatives, infrastructure improvements, and community outreach programs.
# Urban Planning Insight: The results can provide urban planners and transportation professionals with insights on how to target areas for better road safety measures and preventative strategies.
# Policy Implications: This question could help guide policy decisions, potentially influencing zoning and traffic management policies in areas identified as high-risk.
# Next Steps:
# I’ll analyze crash data by borough to assess which areas are the most affected.
# I plan to use bar charts to visualize the frequency and severity of accidents across boroughs and map them to see if geographical patterns exist.
# I may also explore the temporal patterns, such as times of day or days of the week that contribute to higher accident rates, in conjunction with borough-specific data.
# Once I’ve gathered this information, I can provide a comprehensive analysis of high-risk areas and suggest possible interventions to improve traffic safety in New York City.

# %% [markdown]
# **TO DO:** Build a visualization, model, or use other statistical methods to gain insights into your data and to support your research question.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Frequency of crashes by Borough
borough_crashes = data['BOROUGH'].value_counts()

# Severity of crashes by Borough (Injuries and fatalities)
severity_by_borough = data.groupby('BOROUGH').agg({
    'NUMBER OF PERSONS INJURED': 'sum',
    'NUMBER OF PERSONS KILLED': 'sum'
})

# Set the size for the plot
plt.figure(figsize=(14, 7))

# Plotting Frequency of Crashes by Borough
plt.subplot(1, 2, 1)
sns.barplot(x=borough_crashes.index, y=borough_crashes.values, palette="viridis")
plt.title("Frequency of Crashes by Borough")
plt.xlabel("Borough")
plt.ylabel("Number of Crashes")
plt.xticks(rotation=45)

# Plotting Severity of Crashes by Borough
plt.subplot(1, 2, 2)
severity_by_borough[['NUMBER OF PERSONS INJURED', 'NUMBER OF PERSONS KILLED']].plot(kind='bar', stacked=True, ax=plt.gca(), color=sns.color_palette("coolwarm", 2))
plt.title("Crash Severity by Borough (Injuries & Fatalities)")
plt.xlabel("Borough")
plt.ylabel("Count")
plt.xticks(rotation=45)

# Display the plots
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-19-4ff876f917d0>:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=borough_crashes.index, y=borough_crashes.values, palette="viridis")

# %% [markdown]
# ---

# %% [markdown]
# ##<font color='crimson'>**Overall Findings**</font>
#
# 1. Research Question
# Which intersections in New York City experience the highest number of crashes, injuries, and fatalities, and what factors contribute to these outcomes?
# This question was chosen because it aims to address transportation safety at the intersection level, focusing on high-crash zones, and providing actionable insights for city planners and transportation authorities.
# 2. Reason for Selecting Data Visualizations and Models
# Visualizations Chosen:
# Heatmap of Crash Locations: To identify clusters of crashes based on latitude and longitude.
# Bar Graphs by Borough: To compare the frequency of crashes and severity (injuries vs fatalities) by borough.
# Stacked Bar Chart (Injuries and Fatalities by Borough): To visualize the severity distribution and highlight areas that may require more focus for road safety improvements.
# Model/Technique Chosen:
# Geospatial Analysis: Heatmaps were used to visually represent high-crash zones, allowing us to target specific locations in need of intervention.
# Time Series Analysis: To understand how crashes and injuries fluctuate over time, including the impact of external factors like COVID-19 on crash rates.
# 3. Key Insights from Data Analysis
# Crash Clusters: Certain neighborhoods in Brooklyn and Manhattan have higher concentrations of crashes, suggesting that these areas may be more dangerous due to factors such as population density, traffic volume, or inadequate traffic control measures.
# Borough-wise Analysis: Brooklyn reported the highest number of crashes, while Staten Island had the lowest. This can be attributed to factors like urban density, infrastructure, and driving behavior in more suburban boroughs.
# Severity of Crashes: Injuries and fatalities vary significantly across boroughs. Boroughs like Manhattan and Brooklyn show more fatalities, which could indicate more dangerous intersections or higher traffic speeds.
# Impact of COVID-19: The time series analysis revealed a sharp decrease in crashes during the pandemic, particularly in early 2020, as lockdown measures reduced traffic volume.
# 4. Recommendations for the Department of Transportation and Federal Highway Authority
# Target High-Crash Areas: Based on the heatmap and crash data, prioritize safety improvements (e.g., traffic lights, pedestrian crossings, and better signage) in areas with the highest number of crashes.
# Focus on Boroughs with High Fatalities: Manhattan and Brooklyn, with the highest fatalities, should be prioritized for measures to reduce the severity of crashes, such as reducing speed limits and implementing safer pedestrian crossings.
# Improve Intersection Design: Look into the geometric features of intersections, particularly skewed or poorly designed ones, which could contribute to higher crash rates.
# Address Vulnerable Road Users: Pay special attention to pedestrian safety in densely populated areas like Manhattan. Improve crosswalks, pedestrian signals, and enforcement of traffic laws.
# 5. Unanswered Research Questions
# Underrepresented Communities: Further research into whether crashes are disproportionately affecting underrepresented communities could provide more targeted safety recommendations. Data on socioeconomic factors or public transit access could help answer this.
# Effect of Roadway Infrastructure: Understanding the role of infrastructure design (e.g., road width, traffic lights, crosswalks) in influencing crash rates would help to refine safety measures.
# 6. Citation and Acknowledgments
# Citations:
# National Highway Traffic Safety Administration (NHTSA). (2022). Traffic Safety Facts.
# U.S. Department of Transportation. (2021). Data on Traffic Crashes in Urban Areas.
